# %%
# 4 - Let start with selenium

# %%
from selenium import webdriver

# %%
driver = webdriver.Chrome(executable_path = 'chromedriver_linux64')
driver
# Out:
# /tmp/ipykernel_9462/2912314309.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path = 'chromedriver_linux64')
# <selenium.webdriver.chrome.webdriver.WebDriver (session="48892e44c9b6cbe6fa62b71e2f107b80")>

# %%
driver.get('https://codingninjas.in/')

# %%
driver.title
# Out:
# "Coding Ninjas - Learn coding online at India's best coding institute"

# %%
driver.back()

# %%
driver.forward()

# %%
driver.save_screenshot('test_shot.png')
# Out:
# True

# %%
driver.page_source
# Out:
# '<html lang="null"><head>\n    <meta charset="utf-8">\n    <title>Coding Ninjas - Learn coding online at India\'s best coding institute</title>\n\n    <meta name="google-site-verification" content="ASe_HQRsu8j61tGt95RROjXi07M380nMuoJ0Mu9rytk">\n    <meta name="title" content="Coding Ninjas - Learn coding online at India\'s best coding institute">\n    <meta property="og:title" content="Coding Ninjas - Learn coding online at India\'s best coding institute">\n    <meta name="description" content="With live 1:1 mentor support, get your doubts resolved via Audio Call, Video Call and Screen Share from the Teaching Assistants at Coding Ninjas.">\n    <meta property="og:description" content="With live 1:1 mentor support, get your doubts resolved via Audio Call, Video Call and Screen Share from the Teaching Assistants at Coding Ninjas.">\n    <meta property="og:image" content="https://files.codingninjas.in/0000000000000723.jpg">\n\n    <script src="https://connect.facebook.net/signals/config
# ...

# %%
# Depracated
driver.find_element_by_link_text('Register')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 driver.find_element_by_link_text('Register')
#
# AttributeError: 'WebDriver' object has no attribute 'find_element_by_link_text'

# %%
courses_btn = driver.find_element("link text", "Courses")
# courses_btn.click()
courses_btn
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="943f36ca6526659dbc1880a50bb02aba", element="3d2588a9-2b95-438c-b4f8-420ccaa494ad")>

# %%
driver.back()

# %%
courses_btn = driver.find_element("partial link text", "Cour")
courses_btn.click()

# %%
driver.back()

# %%
# 8 - Browser interaction

# %%
driver.maximize_window()

# %%
driver.refresh()

# %%
driver.close()

# %%
# 12 - locate element methods

# %%
driver.get('http://books.toscrape.com/')

# %%
music_btn = driver.find_element("link text", "Music")
music_btn.click()

# %%
kill_btn = driver.find_element("partial link text", "Kill")
kill_btn.click()

# %%
from selenium.webdriver.common.by import By

# %%
kill_btn = driver.find_element(By.CLASS_NAME, "image_container")
kill_btn
kill_btn.click()

# %%
# Find elemetns of a classs
kill_btn = driver.find_elements(By.CLASS_NAME, "image_container")
kill_btn
print(len(kill_btn))
# Out:
# 20

# %%
kill_btn = driver.find_element(By.TAG_NAME, "img")
kill_btn.click()
# save_screenshot(test2.png)

# %%
# 16 - Web element methods and properties

# %%
kill_btn = driver.find_element(By.NAME, "viewport")
type(kill_btn)
# Out:
# selenium.webdriver.remote.webelement.WebElement

# %%
li = driver.find_element(By.CLASS_NAME, "price_color")
li
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="90626c2eecc952557953e936ef2803d8", element="a15ea13a-507b-4f1c-9d39-8445ca88179f")>

# %%
li.click()

# %%
li.text
# Out:
# '£51.77'

# %%
li.tag_name
# Out:
# 'p'

# %%
li.get_attribute('class')
# Out:
# 'price_color'

# %%
get_att = li.get_attribute('href')
type(get_att)
# Out:
# NoneType

# %%
# 21- Find all jobs

# %%
driver.get('http://kanview.ks.gov/PayRates_Agency.aspx')
# Out:
# ---------------------------------------------------------------------------
# TimeoutException                          Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 driver.get('http://kanview.ks.gov/PayRates_Agency.aspx')
#
# File ~/.local/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:449, in WebDriver.get(self, url)
#     447 def get(self, url: str) -> None:
#     448     """Loads a web page in the current browser session."""
# --> 449     self.execute(Command.GET, {"url": url})
#
# File ~/.local/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:440, in WebDriver.execute(self, driver_command, params)
#     438 response = self.command_executor.execute(driver_command, params)
#     439 if response:
# --> 440     self.error_handler.check_response(response)
#     441     response["value"] = self._unwrap_value(response.get("value", None))
#     442     return response
#
# ...

# %%
# from bs4 import BeautifulSoup
import requests

# %%
# req = requests.get('http://kanview.ks.gov/PayRates_Agency.aspx')
res = requests.get('http://kanview.ks.gov/PayRates_Agency.aspx')
res
