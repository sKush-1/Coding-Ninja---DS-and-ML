# %%
import matplotlib.pyplot as plt

# %%
labels = ["A","B","C","D"]
sizes = [3,4,6,2]
colors = ["blue", "purple", "red", "pink"]
explode = [0.1, 0.2, 0, 0]
plt.axis('equal')
plt.title("Split among classes")
plt.pie(sizes,colors=colors,explode = explode,labels = labels, autopct ="%.2f", counterclock = False, startangle=100)
# Out:
# ([<matplotlib.patches.Wedge at 0x14c5528a160>,
#   <matplotlib.patches.Wedge at 0x14c5528a880>,
#   <matplotlib.patches.Wedge at 0x14c5528afa0>,
#   <matplotlib.patches.Wedge at 0x14c55298700>],
#  [Text(0.5260453862450336, 1.078552850633808, 'A'),
#   Text(1.2216003792690735, -0.44462626257302473, 'B'),
#   Text(-0.8426489756979776, -0.7070662654625445, 'C'),
#   Text(-0.6151120429760869, 0.9119414315545625, 'D')],
#  [Text(0.3068598086429362, 0.629155829536388, '20.00'),
#   Text(0.7517540795501989, -0.2736161615833998, '26.67'),
#   Text(-0.4596267140170786, -0.3856725084341151, '40.00'),
#   Text(-0.3355156598051383, 0.49742259902976127, '13.33')])
