# %%
import matplotlib.pyplot as plt

# %%
x = [1,3,3]
y = [2,4,6]

# %%
plt.scatter(x,y, color='red')

# %%
plt.plot(x,y)

# %%
x2 = [3,4,5]
y2 = [2,4,6]

# %%
plt.plot(x2,y2, "b-.")
plt.plot(x,y)

# %%
# plot fucntion x^3
import numpy as np
x = np.arange(0,50,0.1)
y = 2.71 ** x

# plot now
plt.plot(x,y)
